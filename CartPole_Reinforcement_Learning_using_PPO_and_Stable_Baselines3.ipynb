# %% [markdown]
# ### Import Dependencies

# %%
# !pip install stable-baselines3[extra]
# Out:
# Requirement already satisfied: stable-baselines3[extra] in c:\users\aflal\anaconda3\lib\site-packages (2.0.0)
# Requirement already satisfied: matplotlib in c:\users\aflal\anaconda3\lib\site-packages (from stable-baselines3[extra]) (3.7.0)
# Requirement already satisfied: pandas in c:\users\aflal\anaconda3\lib\site-packages (from stable-baselines3[extra]) (1.5.3)
# Requirement already satisfied: numpy>=1.20 in c:\users\aflal\anaconda3\lib\site-packages (from stable-baselines3[extra]) (1.23.5)
# Requirement already satisfied: torch>=1.11 in c:\users\aflal\anaconda3\lib\site-packages (from stable-baselines3[extra]) (2.0.1)
# Requirement already satisfied: cloudpickle in c:\users\aflal\anaconda3\lib\site-packages (from stable-baselines3[extra]) (2.0.0)
# Requirement already satisfied: gymnasium==0.28.1 in c:\users\aflal\anaconda3\lib\site-packages (from stable-baselines3[extra]) (0.28.1)
# Requirement already satisfied: autorom[accept-rom-license]~=0.6.0 in c:\users\aflal\anaconda3\lib\site-packages (from stable-baselines3[extra]) (0.6.1)
# Requirement already satisfied: shimmy[atari]~=0.2.1 in c:\users\aflal\anaconda3\lib\site-packages (from stable-baselines3[extra]) (0.2.1)
# Requirement already satisfied: psutil in c:\users\aflal\anaconda3\lib\site-packages (from stable-baselines3[extra]) (5.9.0)
# Requirement already satisfied: pygame in c:\users\aflal\anaconda3\lib\site-packages (from stable-baselines3[extra]) (2.5.1)
# Requirement already satisfied: rich in c:\users\aflal\anaconda3\lib\site-packages (from stable-baselines3[extra]) (13.5.2)
# Requirement already satisfied: opencv-python in c:\users\aflal\anaconda3\lib\site-packages (from stable-baselines3[extra]) (4.8.0.76)
# Requirement already satisfied: pillow in c:\users\aflal\anaconda3\lib\site-packages (from stable-baselines3[extra]) (9.4.0)
# Requirement already satisfied: tensorboard>=2.9.1 in c:\users\aflal\anaconda3\lib\site-packages (from stable-baselines3[extra]) (2.14.0)
# Requirement already satisfied: tqdm in c:\users\aflal\anaconda3\lib\site-packages (from stable-baselines3[extra]) (4.64.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\users\aflal\anaconda3\lib\site-packages (from gymnasium==0.28.1->stable-baselines3[extra]) (4.4.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in c:\users\aflal\anaconda3\lib\site-packages (from gymnasium==0.28.1->stable-baselines3[extra]) (0.0.4)
# Requirement already satisfied: jax-jumpy>=1.0.0 in c:\users\aflal\anaconda3\lib\site-packages (from gymnasium==0.28.1->stable-baselines3[extra]) (1.0.0)
# Requirement already satisfied: click in c:\users\aflal\anaconda3\lib\site-packages (from autorom[accept-rom-license]~=0.6.0->stable-baselines3[extra]) (8.0.4)
# Requirement already satisfied: requests in c:\users\aflal\anaconda3\lib\site-packages (from autorom[accept-rom-license]~=0.6.0->stable-baselines3[extra]) (2.28.1)
# Requirement already satisfied: AutoROM.accept-rom-license in c:\users\aflal\anaconda3\lib\site-packages (from autorom[accept-rom-license]~=0.6.0->stable-baselines3[extra]) (0.6.1)
# Requirement already satisfied: ale-py~=0.8.1 in c:\users\aflal\anaconda3\lib\site-packages (from shimmy[atari]~=0.2.1->stable-baselines3[extra]) (0.8.1)
# Requirement already satisfied: grpcio>=1.48.2 in c:\users\aflal\anaconda3\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.57.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in c:\users\aflal\anaconda3\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.0.0)
# Requirement already satisfied: wheel>=0.26 in c:\users\aflal\anaconda3\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (0.38.4)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\aflal\anaconda3\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (2.2.2)
# Requirement already satisfied: protobuf>=3.19.6 in c:\users\aflal\anaconda3\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (4.24.0)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\aflal\anaconda3\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (65.6.3)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\aflal\anaconda3\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\aflal\anaconda3\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (0.7.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\aflal\anaconda3\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (2.22.0)
# Requirement already satisfied: absl-py>=0.4 in c:\users\aflal\anaconda3\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.4.0)
# Requirement already satisfied: sympy in c:\users\aflal\anaconda3\lib\site-packages (from torch>=1.11->stable-baselines3[extra]) (1.11.1)
# Requirement already satisfied: jinja2 in c:\users\aflal\anaconda3\lib\site-packages (from torch>=1.11->stable-baselines3[extra]) (3.1.2)
# Requirement already satisfied: filelock in c:\users\aflal\anaconda3\lib\site-packages (from torch>=1.11->stable-baselines3[extra]) (3.9.0)
# Requirement already satisfied: networkx in c:\users\aflal\anaconda3\lib\site-packages (from torch>=1.11->stable-baselines3[extra]) (2.8.4)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\aflal\anaconda3\lib\site-packages (from matplotlib->stable-baselines3[extra]) (4.25.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\aflal\anaconda3\lib\site-packages (from matplotlib->stable-baselines3[extra]) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\aflal\anaconda3\lib\site-packages (from matplotlib->stable-baselines3[extra]) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\aflal\anaconda3\lib\site-packages (from matplotlib->stable-baselines3[extra]) (22.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\aflal\anaconda3\lib\site-packages (from matplotlib->stable-baselines3[extra]) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\aflal\anaconda3\lib\site-packages (from matplotlib->stable-baselines3[extra]) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\aflal\anaconda3\lib\site-packages (from matplotlib->stable-baselines3[extra]) (1.4.4)
# Requirement already satisfied: pytz>=2020.1 in c:\users\aflal\anaconda3\lib\site-packages (from pandas->stable-baselines3[extra]) (2022.7)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\aflal\anaconda3\lib\site-packages (from rich->stable-baselines3[extra]) (2.16.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\aflal\anaconda3\lib\site-packages (from rich->stable-baselines3[extra]) (3.0.0)
# Requirement already satisfied: colorama in c:\users\aflal\anaconda3\lib\site-packages (from tqdm->stable-baselines3[extra]) (0.4.6)
# Requirement already satisfied: importlib-resources in c:\users\aflal\anaconda3\lib\site-packages (from ale-py~=0.8.1->shimmy[atari]~=0.2.1->stable-baselines3[extra]) (6.0.1)
# Requirement already satisfied: urllib3<2.0 in c:\users\aflal\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (1.26.14)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\aflal\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (5.3.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\aflal\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\aflal\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (0.2.8)
# Requirement already satisfied: six>=1.9.0 in c:\users\aflal\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (1.16.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\aflal\anaconda3\lib\site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard>=2.9.1->stable-baselines3[extra]) (1.3.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\aflal\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich->stable-baselines3[extra]) (0.1.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\aflal\anaconda3\lib\site-packages (from requests->autorom[accept-rom-license]~=0.6.0->stable-baselines3[extra]) (2023.5.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\aflal\anaconda3\lib\site-packages (from requests->autorom[accept-rom-license]~=0.6.0->stable-baselines3[extra]) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\aflal\anaconda3\lib\site-packages (from requests->autorom[accept-rom-license]~=0.6.0->stable-baselines3[extra]) (2.0.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\aflal\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard>=2.9.1->stable-baselines3[extra]) (2.1.1)
# Requirement already satisfied: mpmath>=0.19 in c:\users\aflal\anaconda3\lib\site-packages (from sympy->torch>=1.11->stable-baselines3[extra]) (1.2.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\aflal\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\aflal\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard>=2.9.1->stable-baselines3[extra]) (3.2.2)

# %%
# !pip install gym
# Out:
# Requirement already satisfied: gym in c:\users\aflal\anaconda3\lib\site-packages (0.26.2)
# Requirement already satisfied: numpy>=1.18.0 in c:\users\aflal\anaconda3\lib\site-packages (from gym) (1.23.5)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\users\aflal\anaconda3\lib\site-packages (from gym) (2.0.0)
# Requirement already satisfied: gym-notices>=0.0.4 in c:\users\aflal\anaconda3\lib\site-packages (from gym) (0.0.8)

# %%
# !pip3 install torch torchvision torchaudio
# Out:
# Requirement already satisfied: torch in c:\users\aflal\anaconda3\lib\site-packages (2.0.1)
# Requirement already satisfied: torchvision in c:\users\aflal\anaconda3\lib\site-packages (0.15.2)
# Requirement already satisfied: torchaudio in c:\users\aflal\anaconda3\lib\site-packages (2.0.2)
# Requirement already satisfied: sympy in c:\users\aflal\anaconda3\lib\site-packages (from torch) (1.11.1)
# Requirement already satisfied: networkx in c:\users\aflal\anaconda3\lib\site-packages (from torch) (2.8.4)
# Requirement already satisfied: filelock in c:\users\aflal\anaconda3\lib\site-packages (from torch) (3.9.0)
# Requirement already satisfied: jinja2 in c:\users\aflal\anaconda3\lib\site-packages (from torch) (3.1.2)
# Requirement already satisfied: typing-extensions in c:\users\aflal\anaconda3\lib\site-packages (from torch) (4.4.0)
# Requirement already satisfied: numpy in c:\users\aflal\anaconda3\lib\site-packages (from torchvision) (1.23.5)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\aflal\anaconda3\lib\site-packages (from torchvision) (9.4.0)
# Requirement already satisfied: requests in c:\users\aflal\anaconda3\lib\site-packages (from torchvision) (2.28.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\aflal\anaconda3\lib\site-packages (from jinja2->torch) (2.1.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\aflal\anaconda3\lib\site-packages (from requests->torchvision) (1.26.14)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\aflal\anaconda3\lib\site-packages (from requests->torchvision) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\aflal\anaconda3\lib\site-packages (from requests->torchvision) (2023.5.7)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\aflal\anaconda3\lib\site-packages (from requests->torchvision) (2.0.4)
# Requirement already satisfied: mpmath>=0.19 in c:\users\aflal\anaconda3\lib\site-packages (from sympy->torch) (1.2.1)

# %%
import os
import gym
from stable_baselines3 import PPO 
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy
import time

# %% [markdown]
# ### Load Environment

# %%
env = gym.make("CartPole-v1", render_mode="human")
env.action_space.seed(82)
observation, info = env.reset(seed=82)

# %%
env = gym.make("CartPole-v1", render_mode="human")

episodes = 5
for episode in range(1, episodes + 1):    
    state = env.reset()
    done = False
    score = 0

    while not done:
        env.render()
        action = env.action_space.sample()
        n_state, reward, done, done2, info = env.step(action)
        score += reward
        #time.sleep(0.1)
    print('Episode: {} Score {}'.format(episode, score))
#env.close()
# Out:
# Episode: 1 Score 20.0
# Episode: 2 Score 13.0
# Episode: 3 Score 18.0
# Episode: 4 Score 77.0
# Episode: 5 Score 19.0

# %%
env.close()

# %% [markdown]
# ### Train RL Model

# %%
log_path = os.path.join('Training','Logs')

# %%
log_path
# Out:
# 'Training\\Logs'

# %%
#env = gym.make("CartPole-v1", render_mode="human")
#env = DummyVecEnv([lambda: env])
#model = PPO('MlpPolicy', env, verbose=1, tensorboard_log=log_path)

# %%
def make_env():
    return gym.make("CartPole-v1", render_mode="human")

env = [make_env]
env = DummyVecEnv(env)  # Create the vectorized environment
model = PPO('MlpPolicy', env, verbose=1, tensorboard_log=log_path)
# Out:
# Using cpu device

# %%
PPO?

# %%
model.learn(total_timesteps=20000)
# Out:
# Logging to Training\Logs\PPO_14
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[290], line 1
# ----> 1 model.learn(total_timesteps=20000)
#
# File ~\anaconda3\lib\site-packages\stable_baselines3\ppo\ppo.py:308, in PPO.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     299 def learn(
#     300     self: SelfPPO,
#     301     total_timesteps: int,
#    (...)
#     306     progress_bar: bool = False,
#     307 ) -> SelfPPO:
# --> 308     return super().learn(
#     309         total_timesteps=total_timesteps,
#     310         callback=callback,
#     311         log_interval=log_interval,
#     312         tb_log_name=tb_log_name,
#     313         reset_num_timesteps=reset_num_timesteps,
#     314         progress_bar=progress_bar,
#     315     )
#
# File ~\anaconda3\lib\site-packages\stable_baselines3\common\on_policy_algorithm.py:259, in OnPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     256 assert self.env is not None
#     258 while self.num_timesteps < total_timesteps:
# --> 259     continue_training = self.collect_rollouts(self.env, callback, self.rollout_buffer, n_rollout_steps=self.n_steps)
#     261     if continue_training is False:
#     262         break
#
# File ~\anaconda3\lib\site-packages\stable_baselines3\common\on_policy_algorithm.py:178, in OnPolicyAlgorithm.collect_rollouts(self, env, callback, rollout_buffer, n_rollout_steps)
#     175 if isinstance(self.action_space, spaces.Box):
#     176     clipped_actions = np.clip(actions, self.action_space.low, self.action_space.high)
# --> 178 new_obs, rewards, dones, infos = env.step(clipped_actions)
#     180 self.num_timesteps += env.num_envs
#     182 # Give access to local variables
#
# File ~\anaconda3\lib\site-packages\stable_baselines3\common\vec_env\base_vec_env.py:197, in VecEnv.step(self, actions)
#     190 """
#     191 Step the environments with the given action
#     192
#     193 :param actions: the action
#     194 :return: observation, reward, done, information
#     195 """
#     196 self.step_async(actions)
# --> 197 return self.step_wait()
#
# File ~\anaconda3\lib\site-packages\stable_baselines3\common\vec_env\dummy_vec_env.py:70, in DummyVecEnv.step_wait(self)
#      67     if self.buf_dones[env_idx]:
#      68         # save final observation where user can get it, then reset
#      69         self.buf_infos[env_idx]["terminal_observation"] = obs
# ---> 70         obs, self.reset_infos[env_idx] = self.envs[env_idx].reset()
#      71     self._save_obs(env_idx, obs)
#      72 return (self._obs_from_buf(), np.copy(self.buf_rews), np.copy(self.buf_dones), deepcopy(self.buf_infos))
#
# File ~\anaconda3\lib\site-packages\shimmy\openai_gym_compatibility.py:112, in GymV26CompatibilityV0.reset(self, seed, options)
#     110 super().reset(seed=seed)
#     111 # Options are ignored
# --> 112 return self.gym_env.reset(seed=seed, options=options)
#
# File ~\anaconda3\lib\site-packages\gym\wrappers\time_limit.py:68, in TimeLimit.reset(self, **kwargs)
#      59 """Resets the environment with :param:`**kwargs` and sets the number of steps elapsed to zero.
#      60
#      61 Args:
#    (...)
#      65     The reset environment
#      66 """
#      67 self._elapsed_steps = 0
# ---> 68 return self.env.reset(**kwargs)
#
# File ~\anaconda3\lib\site-packages\gym\wrappers\order_enforcing.py:42, in OrderEnforcing.reset(self, **kwargs)
#      40 """Resets the environment with `kwargs`."""
#      41 self._has_reset = True
# ---> 42 return self.env.reset(**kwargs)
#
# File ~\anaconda3\lib\site-packages\gym\wrappers\env_checker.py:47, in PassiveEnvChecker.reset(self, **kwargs)
#      45     return env_reset_passive_checker(self.env, **kwargs)
#      46 else:
# ---> 47     return self.env.reset(**kwargs)
#
# File ~\anaconda3\lib\site-packages\gym\envs\classic_control\cartpole.py:206, in CartPoleEnv.reset(self, seed, options)
#     203 self.steps_beyond_terminated = None
#     205 if self.render_mode == "human":
# --> 206     self.render()
#     207 return np.array(self.state, dtype=np.float32), {}
#
# File ~\anaconda3\lib\site-packages\gym\envs\classic_control\cartpole.py:298, in CartPoleEnv.render(self)
#     296 if self.render_mode == "human":
#     297     pygame.event.pump()
# --> 298     self.clock.tick(self.metadata["render_fps"])
#     299     pygame.display.flip()
#     301 elif self.render_mode == "rgb_array":
#
# KeyboardInterrupt:

# %% [markdown]
# ### Save and Reload

# %%
PPO_path = os.path.join('Training', 'Saved Models', 'PPO_Model_cartpole')

# %%
model.save(PPO_path)

# %%
del model

# %%
model.learn(total_timesteps=1000)
# Out:
# Logging to Training\Logs\PPO_11
# -----------------------------
# | time/              |      |
# |    fps             | 46   |
# |    iterations      | 1    |
# |    time_elapsed    | 43   |
# |    total_timesteps | 2048 |
# -----------------------------

# %%
model = PPO.load(PPO_path, env = env)

# %% [markdown]
# ### Evaluation

# %%
evaluate_policy(model, env, n_eval_episodes=3, render=True)
# Out:
# (500.0, 0.0)

# %%
env.close()

# %% [markdown]
# ### Testing Agent

# %%
env = gym.make("CartPole-v1", render_mode="human")
env.action_space.seed(82)
observation, info = env.reset(seed=82)
env = DummyVecEnv([lambda: env])

episodes = 5
for episode in range(1, episodes + 1):    
    obs = env.reset()
    done = False
    score = 0

    while not done:
        env.render()
        action, _ = model.predict(obs)
        obs, reward, done, info = env.step(action)
        score += reward
        #time.sleep(0.1)
    print('Episode: {} Score {}'.format(episode, score))
#env.close()
# Out:
# Episode: 1 Score [285.]
# Episode: 2 Score [363.]
# Episode: 3 Score [500.]
# Episode: 4 Score [115.]
# Episode: 5 Score [110.]

# %%
env.close()

# %% [markdown]
# ###  Tensorboard Visualization

# %%
training_log_path = os.path.join(log_path, 'PPO_1')

# %%
training_log_path
# Out:
# 'Training\\Logs\\PPO_1'

# %%
# !tensorboard --logdir={training_log_path}
# Out:
# ^C

# %% [markdown]
# ### Call back to the Training Stage

# %%
from stable_baselines3.common.callbacks import EvalCallback, StopTrainingOnRewardThreshold

# %%
save_path = os.path.join('Training', 'Saved Model')

# %%
stop_callback = StopTrainingOnRewardThreshold(reward_threshold=500, verbose=1)
eval_callback = EvalCallback(env,
                            callback_on_new_best=stop_callback,
                            eval_freq=3000,
                            best_model_save_path=save_path,
                            verbose=1,
                            render=False
                            )

# %%
model = PPO('MlpPolicy', env, verbose=1, tensorboard_log=log_path)
# Out:
# Using cpu device

# %%
model.learn(total_timesteps=20000, callback=eval_callback)
# Out:
# Logging to Training\Logs\PPO_16
# -----------------------------
# | time/              |      |
# |    fps             | 46   |
# |    iterations      | 1    |
# |    time_elapsed    | 43   |
# |    total_timesteps | 2048 |
# -----------------------------
# Eval num_timesteps=3000, episode_reward=198.80 +/- 13.91
# Episode length: 198.80 +/- 13.91
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 199         |
# |    mean_reward          | 199         |
# | time/                   |             |
# |    total_timesteps      | 3000        |
# | train/                  |             |
# |    approx_kl            | 0.008206619 |
# |    clip_fraction        | 0.124       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.686      |
# |    explained_variance   | 0.0147      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.2        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0194     |
# |    value_loss           | 60.4        |
# -----------------------------------------
# New best mean reward!
# -----------------------------
# | time/              |      |
# |    fps             | 37   |
# |    iterations      | 2    |
# |    time_elapsed    | 108  |
# |    total_timesteps | 4096 |
# -----------------------------
# Eval num_timesteps=6000, episode_reward=348.60 +/- 83.71
# Episode length: 348.60 +/- 83.71
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 349         |
# |    mean_reward          | 349         |
# | time/                   |             |
# |    total_timesteps      | 6000        |
# | train/                  |             |
# |    approx_kl            | 0.007954599 |
# |    clip_fraction        | 0.0502      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.665      |
# |    explained_variance   | 0.0467      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 16          |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.015      |
# |    value_loss           | 41.3        |
# -----------------------------------------
# New best mean reward!
# -----------------------------
# | time/              |      |
# |    fps             | 32   |
# |    iterations      | 3    |
# |    time_elapsed    | 188  |
# |    total_timesteps | 6144 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 35          |
# |    iterations           | 4           |
# |    time_elapsed         | 232         |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.009608299 |
# |    clip_fraction        | 0.0829      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.639      |
# |    explained_variance   | 0.221       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 22.7        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.018      |
# |    value_loss           | 54.4        |
# -----------------------------------------
# Eval num_timesteps=9000, episode_reward=312.40 +/- 95.29
# Episode length: 312.40 +/- 95.29
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 312         |
# |    mean_reward          | 312         |
# | time/                   |             |
# |    total_timesteps      | 9000        |
# | train/                  |             |
# |    approx_kl            | 0.008593921 |
# |    clip_fraction        | 0.089       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.603      |
# |    explained_variance   | 0.279       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 25.7        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0193     |
# |    value_loss           | 66.6        |
# -----------------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 33    |
# |    iterations      | 5     |
# |    time_elapsed    | 307   |
# |    total_timesteps | 10240 |
# ------------------------------
# Eval num_timesteps=12000, episode_reward=432.80 +/- 91.44
# Episode length: 432.80 +/- 91.44
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 433         |
# |    mean_reward          | 433         |
# | time/                   |             |
# |    total_timesteps      | 12000       |
# | train/                  |             |
# |    approx_kl            | 0.005746527 |
# |    clip_fraction        | 0.0438      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.595      |
# |    explained_variance   | 0.279       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 33.4        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0107     |
# |    value_loss           | 66.7        |
# -----------------------------------------
# New best mean reward!
# ------------------------------
# | time/              |       |
# |    fps             | 31    |
# |    iterations      | 6     |
# |    time_elapsed    | 395   |
# |    total_timesteps | 12288 |
# ------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 32           |
# |    iterations           | 7            |
# |    time_elapsed         | 437          |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0045717238 |
# |    clip_fraction        | 0.043        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.591       |
# |    explained_variance   | 0.507        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 14.7         |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00652     |
# |    value_loss           | 57.2         |
# ------------------------------------------
# Eval num_timesteps=15000, episode_reward=466.60 +/- 66.80
# Episode length: 466.60 +/- 66.80
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 467          |
# |    mean_reward          | 467          |
# | time/                   |              |
# |    total_timesteps      | 15000        |
# | train/                  |              |
# |    approx_kl            | 0.0037987852 |
# |    clip_fraction        | 0.03         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.569       |
# |    explained_variance   | 0.621        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 12.7         |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00782     |
# |    value_loss           | 53           |
# ------------------------------------------
# New best mean reward!
# ------------------------------
# | time/              |       |
# |    fps             | 30    |
# |    iterations      | 8     |
# |    time_elapsed    | 528   |
# |    total_timesteps | 16384 |
# ------------------------------
# Eval num_timesteps=18000, episode_reward=494.20 +/- 11.60
# Episode length: 494.20 +/- 11.60
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 494         |
# |    mean_reward          | 494         |
# | time/                   |             |
# |    total_timesteps      | 18000       |
# | train/                  |             |
# |    approx_kl            | 0.005793501 |
# |    clip_fraction        | 0.0585      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.569      |
# |    explained_variance   | 0.835       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 28.8        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0117     |
# |    value_loss           | 32.9        |
# -----------------------------------------
# New best mean reward!
# ------------------------------
# | time/              |       |
# |    fps             | 29    |
# |    iterations      | 9     |
# |    time_elapsed    | 622   |
# |    total_timesteps | 18432 |
# ------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 30           |
# |    iterations           | 10           |
# |    time_elapsed         | 665          |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0043251826 |
# |    clip_fraction        | 0.0298       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.542       |
# |    explained_variance   | 0.744        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.49         |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00423     |
# |    value_loss           | 29.7         |
# ------------------------------------------

# %% [markdown]
# ### Changing Policies

# %%
net_arch = [dict(pi=[128,128,128,128], vf=[128,128,128,128])]

# %%
model = PPO('MlpPolicy', env, verbose=1, tensorboard_log=log_path, policy_kwargs={'net_arch':net_arch})
# Out:
# Using cpu device
# C:\Users\aflal\anaconda3\lib\site-packages\stable_baselines3\common\policies.py:460: UserWarning: As shared layers in the mlp_extractor are removed since SB3 v1.8.0, you should now pass directly a dictionary and not a list (net_arch=dict(pi=..., vf=...) instead of net_arch=[dict(pi=..., vf=...)])
#   warnings.warn(

# %%
model.learn(total_timesteps=20000, callback=eval_callback)
# Out:
# Logging to Training\Logs\PPO_17
# Eval num_timesteps=520, episode_reward=9.80 +/- 0.40
# Episode length: 9.80 +/- 0.40
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 9.8      |
# |    mean_reward     | 9.8      |
# | time/              |          |
# |    total_timesteps | 520      |
# ---------------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 45   |
# |    iterations      | 1    |
# |    time_elapsed    | 45   |
# |    total_timesteps | 2048 |
# -----------------------------
# Eval num_timesteps=3520, episode_reward=338.20 +/- 134.25
# Episode length: 338.20 +/- 134.25
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 338         |
# |    mean_reward          | 338         |
# | time/                   |             |
# |    total_timesteps      | 3520        |
# | train/                  |             |
# |    approx_kl            | 0.014095473 |
# |    clip_fraction        | 0.175       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.682      |
# |    explained_variance   | 0.0042      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.8         |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0189     |
# |    value_loss           | 19.4        |
# -----------------------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 32   |
# |    iterations      | 2    |
# |    time_elapsed    | 125  |
# |    total_timesteps | 4096 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 36          |
# |    iterations           | 3           |
# |    time_elapsed         | 169         |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.018963784 |
# |    clip_fraction        | 0.256       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.637      |
# |    explained_variance   | 0.423       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.4        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0397     |
# |    value_loss           | 26.2        |
# -----------------------------------------
# Eval num_timesteps=6520, episode_reward=375.60 +/- 146.80
# Episode length: 375.60 +/- 146.80
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 376         |
# |    mean_reward          | 376         |
# | time/                   |             |
# |    total_timesteps      | 6520        |
# | train/                  |             |
# |    approx_kl            | 0.016411927 |
# |    clip_fraction        | 0.152       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.592      |
# |    explained_variance   | 0.376       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 13.5        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0239     |
# |    value_loss           | 40.4        |
# -----------------------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 32   |
# |    iterations      | 4    |
# |    time_elapsed    | 251  |
# |    total_timesteps | 8192 |
# -----------------------------
# Eval num_timesteps=9520, episode_reward=403.40 +/- 118.43
# Episode length: 403.40 +/- 118.43
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 403         |
# |    mean_reward          | 403         |
# | time/                   |             |
# |    total_timesteps      | 9520        |
# | train/                  |             |
# |    approx_kl            | 0.010132244 |
# |    clip_fraction        | 0.112       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.562      |
# |    explained_variance   | 0.503       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.88        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0164     |
# |    value_loss           | 30.3        |
# -----------------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 30    |
# |    iterations      | 5     |
# |    time_elapsed    | 337   |
# |    total_timesteps | 10240 |
# ------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 6           |
# |    time_elapsed         | 381         |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.010523332 |
# |    clip_fraction        | 0.148       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.551      |
# |    explained_variance   | 0.902       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.62        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0246     |
# |    value_loss           | 18.9        |
# -----------------------------------------
# Eval num_timesteps=12520, episode_reward=500.00 +/- 0.00
# Episode length: 500.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 500         |
# |    mean_reward          | 500         |
# | time/                   |             |
# |    total_timesteps      | 12520       |
# | train/                  |             |
# |    approx_kl            | 0.012534447 |
# |    clip_fraction        | 0.187       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.559      |
# |    explained_variance   | 0.941       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.62        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0246     |
# |    value_loss           | 13.5        |
# -----------------------------------------
# New best mean reward!
# Stopping training because the mean reward 500.00  is above the threshold 500

# %% [markdown]
# ### Using Alternate Algorithm

# %%
from stable_baselines3 import DQN

# %%
model = DQN('MlpPolicy', env, verbose=1, tensorboard_log=log_path)
# Out:
# Using cpu device

# %%
model.learn(total_timesteps=20000)
# Out:
# Logging to Training\Logs\DQN_1
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.964    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 46       |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 75       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.911    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 46       |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 188      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.855    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 46       |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 306      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.815    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 46       |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 389      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.783    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 46       |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 456      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.755    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 46       |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 515      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.721    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 46       |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 588      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.669    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 46       |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 696      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.64     |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 46       |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 757      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.597    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 46       |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 849      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.57     |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 46       |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 906      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.533    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 46       |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 983      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.502    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 46       |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 1048     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.476    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 46       |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 1103     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.438    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 46       |
# |    time_elapsed     | 25       |
# |    total_timesteps  | 1184     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.383    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 46       |
# |    time_elapsed     | 28       |
# |    total_timesteps  | 1299     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.343    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 46       |
# |    time_elapsed     | 29       |
# |    total_timesteps  | 1383     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.299    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 46       |
# |    time_elapsed     | 31       |
# |    total_timesteps  | 1476     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.27     |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 46       |
# |    time_elapsed     | 33       |
# |    total_timesteps  | 1536     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.229    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 46       |
# |    time_elapsed     | 35       |
# |    total_timesteps  | 1623     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.202    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 46       |
# |    time_elapsed     | 36       |
# |    total_timesteps  | 1679     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.167    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 46       |
# |    time_elapsed     | 37       |
# |    total_timesteps  | 1753     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.119    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 46       |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 1855     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0885   |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 46       |
# |    time_elapsed     | 41       |
# |    total_timesteps  | 1919     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 46       |
# |    time_elapsed     | 43       |
# |    total_timesteps  | 2007     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 46       |
# |    time_elapsed     | 45       |
# |    total_timesteps  | 2117     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 46       |
# |    time_elapsed     | 47       |
# |    total_timesteps  | 2196     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 46       |
# |    time_elapsed     | 48       |
# |    total_timesteps  | 2258     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 46       |
# |    time_elapsed     | 50       |
# |    total_timesteps  | 2317     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 46       |
# |    time_elapsed     | 52       |
# |    total_timesteps  | 2409     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 46       |
# |    time_elapsed     | 53       |
# |    total_timesteps  | 2478     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 46       |
# |    time_elapsed     | 57       |
# |    total_timesteps  | 2671     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 46       |
# |    time_elapsed     | 60       |
# |    total_timesteps  | 2789     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 46       |
# |    time_elapsed     | 61       |
# |    total_timesteps  | 2868     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 46       |
# |    time_elapsed     | 62       |
# |    total_timesteps  | 2920     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 46       |
# |    time_elapsed     | 64       |
# |    total_timesteps  | 3005     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 46       |
# |    time_elapsed     | 68       |
# |    total_timesteps  | 3157     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 46       |
# |    time_elapsed     | 70       |
# |    total_timesteps  | 3258     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 46       |
# |    time_elapsed     | 72       |
# |    total_timesteps  | 3374     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 46       |
# |    time_elapsed     | 74       |
# |    total_timesteps  | 3451     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 46       |
# |    time_elapsed     | 76       |
# |    total_timesteps  | 3531     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 46       |
# |    time_elapsed     | 78       |
# |    total_timesteps  | 3624     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 46       |
# |    time_elapsed     | 80       |
# |    total_timesteps  | 3736     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 46       |
# |    time_elapsed     | 82       |
# |    total_timesteps  | 3849     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 46       |
# |    time_elapsed     | 84       |
# |    total_timesteps  | 3923     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 46       |
# |    time_elapsed     | 86       |
# |    total_timesteps  | 4005     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 46       |
# |    time_elapsed     | 88       |
# |    total_timesteps  | 4102     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 46       |
# |    time_elapsed     | 89       |
# |    total_timesteps  | 4170     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 46       |
# |    time_elapsed     | 91       |
# |    total_timesteps  | 4266     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 46       |
# |    time_elapsed     | 94       |
# |    total_timesteps  | 4380     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 46       |
# |    time_elapsed     | 96       |
# |    total_timesteps  | 4464     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 46       |
# |    time_elapsed     | 98       |
# |    total_timesteps  | 4562     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 46       |
# |    time_elapsed     | 100      |
# |    total_timesteps  | 4677     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 46       |
# |    time_elapsed     | 102      |
# |    total_timesteps  | 4775     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 46       |
# |    time_elapsed     | 104      |
# |    total_timesteps  | 4880     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 46       |
# |    time_elapsed     | 106      |
# |    total_timesteps  | 4975     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 46       |
# |    time_elapsed     | 108      |
# |    total_timesteps  | 5038     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 46       |
# |    time_elapsed     | 110      |
# |    total_timesteps  | 5121     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 46       |
# |    time_elapsed     | 112      |
# |    total_timesteps  | 5221     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 46       |
# |    time_elapsed     | 115      |
# |    total_timesteps  | 5370     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 46       |
# |    time_elapsed     | 117      |
# |    total_timesteps  | 5463     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 46       |
# |    time_elapsed     | 119      |
# |    total_timesteps  | 5562     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 46       |
# |    time_elapsed     | 122      |
# |    total_timesteps  | 5686     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 46       |
# |    time_elapsed     | 123      |
# |    total_timesteps  | 5766     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 46       |
# |    time_elapsed     | 125      |
# |    total_timesteps  | 5845     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 46       |
# |    time_elapsed     | 127      |
# |    total_timesteps  | 5924     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 46       |
# |    time_elapsed     | 129      |
# |    total_timesteps  | 6001     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 46       |
# |    time_elapsed     | 130      |
# |    total_timesteps  | 6079     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 46       |
# |    time_elapsed     | 132      |
# |    total_timesteps  | 6149     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 46       |
# |    time_elapsed     | 134      |
# |    total_timesteps  | 6237     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 46       |
# |    time_elapsed     | 136      |
# |    total_timesteps  | 6334     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 46       |
# |    time_elapsed     | 138      |
# |    total_timesteps  | 6430     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 46       |
# |    time_elapsed     | 139      |
# |    total_timesteps  | 6482     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 46       |
# |    time_elapsed     | 141      |
# |    total_timesteps  | 6595     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 46       |
# |    time_elapsed     | 143      |
# |    total_timesteps  | 6674     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 46       |
# |    time_elapsed     | 145      |
# |    total_timesteps  | 6743     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 46       |
# |    time_elapsed     | 147      |
# |    total_timesteps  | 6862     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 46       |
# |    time_elapsed     | 149      |
# |    total_timesteps  | 6947     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 46       |
# |    time_elapsed     | 151      |
# |    total_timesteps  | 7023     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 46       |
# |    time_elapsed     | 153      |
# |    total_timesteps  | 7138     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 46       |
# |    time_elapsed     | 155      |
# |    total_timesteps  | 7211     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 46       |
# |    time_elapsed     | 157      |
# |    total_timesteps  | 7328     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 46       |
# |    time_elapsed     | 159      |
# |    total_timesteps  | 7396     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 46       |
# |    time_elapsed     | 160      |
# |    total_timesteps  | 7463     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 46       |
# |    time_elapsed     | 163      |
# |    total_timesteps  | 7588     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 46       |
# |    time_elapsed     | 164      |
# |    total_timesteps  | 7643     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 46       |
# |    time_elapsed     | 165      |
# |    total_timesteps  | 7710     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 46       |
# |    time_elapsed     | 167      |
# |    total_timesteps  | 7792     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 46       |
# |    time_elapsed     | 169      |
# |    total_timesteps  | 7857     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 46       |
# |    time_elapsed     | 171      |
# |    total_timesteps  | 7997     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 46       |
# |    time_elapsed     | 174      |
# |    total_timesteps  | 8134     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 46       |
# |    time_elapsed     | 177      |
# |    total_timesteps  | 8261     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 46       |
# |    time_elapsed     | 179      |
# |    total_timesteps  | 8347     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 46       |
# |    time_elapsed     | 180      |
# |    total_timesteps  | 8410     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 46       |
# |    time_elapsed     | 183      |
# |    total_timesteps  | 8552     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 384      |
# |    fps              | 46       |
# |    time_elapsed     | 185      |
# |    total_timesteps  | 8640     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 388      |
# |    fps              | 46       |
# |    time_elapsed     | 187      |
# |    total_timesteps  | 8705     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 392      |
# |    fps              | 46       |
# |    time_elapsed     | 188      |
# |    total_timesteps  | 8776     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 396      |
# |    fps              | 46       |
# |    time_elapsed     | 190      |
# |    total_timesteps  | 8881     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 400      |
# |    fps              | 46       |
# |    time_elapsed     | 192      |
# |    total_timesteps  | 8966     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 404      |
# |    fps              | 46       |
# |    time_elapsed     | 194      |
# |    total_timesteps  | 9058     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 408      |
# |    fps              | 46       |
# |    time_elapsed     | 196      |
# |    total_timesteps  | 9127     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 412      |
# |    fps              | 46       |
# |    time_elapsed     | 198      |
# |    total_timesteps  | 9226     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 416      |
# |    fps              | 46       |
# |    time_elapsed     | 200      |
# |    total_timesteps  | 9351     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 420      |
# |    fps              | 46       |
# |    time_elapsed     | 202      |
# |    total_timesteps  | 9431     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 424      |
# |    fps              | 46       |
# |    time_elapsed     | 204      |
# |    total_timesteps  | 9506     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 428      |
# |    fps              | 46       |
# |    time_elapsed     | 206      |
# |    total_timesteps  | 9589     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 432      |
# |    fps              | 46       |
# |    time_elapsed     | 208      |
# |    total_timesteps  | 9683     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 436      |
# |    fps              | 46       |
# |    time_elapsed     | 211      |
# |    total_timesteps  | 9831     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 440      |
# |    fps              | 46       |
# |    time_elapsed     | 212      |
# |    total_timesteps  | 9910     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 444      |
# |    fps              | 46       |
# |    time_elapsed     | 215      |
# |    total_timesteps  | 10041    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 448      |
# |    fps              | 46       |
# |    time_elapsed     | 217      |
# |    total_timesteps  | 10134    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 452      |
# |    fps              | 46       |
# |    time_elapsed     | 219      |
# |    total_timesteps  | 10212    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 456      |
# |    fps              | 46       |
# |    time_elapsed     | 221      |
# |    total_timesteps  | 10295    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 460      |
# |    fps              | 46       |
# |    time_elapsed     | 222      |
# |    total_timesteps  | 10355    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 464      |
# |    fps              | 46       |
# |    time_elapsed     | 224      |
# |    total_timesteps  | 10469    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 468      |
# |    fps              | 46       |
# |    time_elapsed     | 227      |
# |    total_timesteps  | 10576    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 472      |
# |    fps              | 46       |
# |    time_elapsed     | 228      |
# |    total_timesteps  | 10665    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 476      |
# |    fps              | 46       |
# |    time_elapsed     | 231      |
# |    total_timesteps  | 10763    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 480      |
# |    fps              | 46       |
# |    time_elapsed     | 232      |
# |    total_timesteps  | 10822    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 484      |
# |    fps              | 46       |
# |    time_elapsed     | 233      |
# |    total_timesteps  | 10881    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 488      |
# |    fps              | 46       |
# |    time_elapsed     | 235      |
# |    total_timesteps  | 10958    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 492      |
# |    fps              | 46       |
# |    time_elapsed     | 236      |
# |    total_timesteps  | 11031    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 496      |
# |    fps              | 46       |
# |    time_elapsed     | 238      |
# |    total_timesteps  | 11108    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 500      |
# |    fps              | 46       |
# |    time_elapsed     | 240      |
# |    total_timesteps  | 11208    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 504      |
# |    fps              | 46       |
# |    time_elapsed     | 242      |
# |    total_timesteps  | 11305    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 508      |
# |    fps              | 46       |
# |    time_elapsed     | 244      |
# |    total_timesteps  | 11384    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 512      |
# |    fps              | 46       |
# |    time_elapsed     | 246      |
# |    total_timesteps  | 11460    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 516      |
# |    fps              | 46       |
# |    time_elapsed     | 248      |
# |    total_timesteps  | 11568    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 520      |
# |    fps              | 46       |
# |    time_elapsed     | 249      |
# |    total_timesteps  | 11622    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 524      |
# |    fps              | 46       |
# |    time_elapsed     | 252      |
# |    total_timesteps  | 11745    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 528      |
# |    fps              | 46       |
# |    time_elapsed     | 253      |
# |    total_timesteps  | 11821    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 532      |
# |    fps              | 46       |
# |    time_elapsed     | 255      |
# |    total_timesteps  | 11908    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 536      |
# |    fps              | 46       |
# |    time_elapsed     | 256      |
# |    total_timesteps  | 11959    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 540      |
# |    fps              | 46       |
# |    time_elapsed     | 258      |
# |    total_timesteps  | 12015    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 544      |
# |    fps              | 46       |
# |    time_elapsed     | 259      |
# |    total_timesteps  | 12080    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 548      |
# |    fps              | 46       |
# |    time_elapsed     | 262      |
# |    total_timesteps  | 12204    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 552      |
# |    fps              | 46       |
# |    time_elapsed     | 264      |
# |    total_timesteps  | 12295    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 556      |
# |    fps              | 46       |
# |    time_elapsed     | 265      |
# |    total_timesteps  | 12370    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 560      |
# |    fps              | 46       |
# |    time_elapsed     | 268      |
# |    total_timesteps  | 12479    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 564      |
# |    fps              | 46       |
# |    time_elapsed     | 270      |
# |    total_timesteps  | 12601    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 568      |
# |    fps              | 46       |
# |    time_elapsed     | 272      |
# |    total_timesteps  | 12701    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 572      |
# |    fps              | 46       |
# |    time_elapsed     | 274      |
# |    total_timesteps  | 12788    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 576      |
# |    fps              | 46       |
# |    time_elapsed     | 276      |
# |    total_timesteps  | 12882    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 580      |
# |    fps              | 46       |
# |    time_elapsed     | 278      |
# |    total_timesteps  | 12951    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 584      |
# |    fps              | 46       |
# |    time_elapsed     | 280      |
# |    total_timesteps  | 13042    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 588      |
# |    fps              | 46       |
# |    time_elapsed     | 281      |
# |    total_timesteps  | 13128    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 592      |
# |    fps              | 46       |
# |    time_elapsed     | 283      |
# |    total_timesteps  | 13222    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 596      |
# |    fps              | 46       |
# |    time_elapsed     | 286      |
# |    total_timesteps  | 13329    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 600      |
# |    fps              | 46       |
# |    time_elapsed     | 287      |
# |    total_timesteps  | 13404    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 604      |
# |    fps              | 46       |
# |    time_elapsed     | 289      |
# |    total_timesteps  | 13488    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 608      |
# |    fps              | 46       |
# |    time_elapsed     | 291      |
# |    total_timesteps  | 13554    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# ...
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 696      |
# |    fps              | 46       |
# |    time_elapsed     | 333      |
# |    total_timesteps  | 15512    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 700      |
# |    fps              | 46       |
# |    time_elapsed     | 335      |
# |    total_timesteps  | 15620    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 704      |
# |    fps              | 46       |
# |    time_elapsed     | 336      |
# |    total_timesteps  | 15687    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 708      |
# |    fps              | 46       |
# |    time_elapsed     | 338      |
# |    total_timesteps  | 15764    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 712      |
# |    fps              | 46       |
# |    time_elapsed     | 340      |
# |    total_timesteps  | 15857    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 716      |
# |    fps              | 46       |
# |    time_elapsed     | 342      |
# |    total_timesteps  | 15942    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 720      |
# |    fps              | 46       |
# |    time_elapsed     | 344      |
# |    total_timesteps  | 16022    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 724      |
# |    fps              | 46       |
# |    time_elapsed     | 345      |
# |    total_timesteps  | 16112    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 728      |
# |    fps              | 46       |
# |    time_elapsed     | 348      |
# |    total_timesteps  | 16209    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 732      |
# |    fps              | 46       |
# |    time_elapsed     | 349      |
# |    total_timesteps  | 16279    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 736      |
# |    fps              | 46       |
# |    time_elapsed     | 352      |
# |    total_timesteps  | 16414    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 740      |
# |    fps              | 46       |
# |    time_elapsed     | 354      |
# |    total_timesteps  | 16524    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 744      |
# |    fps              | 46       |
# |    time_elapsed     | 357      |
# |    total_timesteps  | 16627    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 748      |
# |    fps              | 46       |
# |    time_elapsed     | 359      |
# |    total_timesteps  | 16724    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 752      |
# |    fps              | 46       |
# |    time_elapsed     | 360      |
# |    total_timesteps  | 16804    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 756      |
# |    fps              | 46       |
# |    time_elapsed     | 362      |
# |    total_timesteps  | 16861    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 760      |
# |    fps              | 46       |
# |    time_elapsed     | 364      |
# |    total_timesteps  | 16975    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 764      |
# |    fps              | 46       |
# |    time_elapsed     | 365      |
# |    total_timesteps  | 17036    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 768      |
# |    fps              | 46       |
# |    time_elapsed     | 367      |
# |    total_timesteps  | 17107    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 772      |
# |    fps              | 46       |
# |    time_elapsed     | 369      |
# |    total_timesteps  | 17197    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 776      |
# |    fps              | 46       |
# |    time_elapsed     | 370      |
# |    total_timesteps  | 17265    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 780      |
# |    fps              | 46       |
# |    time_elapsed     | 372      |
# |    total_timesteps  | 17339    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 784      |
# |    fps              | 46       |
# |    time_elapsed     | 374      |
# |    total_timesteps  | 17442    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 788      |
# |    fps              | 46       |
# |    time_elapsed     | 376      |
# |    total_timesteps  | 17532    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 792      |
# |    fps              | 46       |
# |    time_elapsed     | 378      |
# |    total_timesteps  | 17607    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 796      |
# |    fps              | 46       |
# |    time_elapsed     | 379      |
# |    total_timesteps  | 17674    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 800      |
# |    fps              | 46       |
# |    time_elapsed     | 381      |
# |    total_timesteps  | 17747    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 804      |
# |    fps              | 46       |
# |    time_elapsed     | 383      |
# |    total_timesteps  | 17854    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 808      |
# |    fps              | 46       |
# |    time_elapsed     | 385      |
# |    total_timesteps  | 17939    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 812      |
# |    fps              | 46       |
# |    time_elapsed     | 387      |
# |    total_timesteps  | 18021    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 816      |
# |    fps              | 46       |
# |    time_elapsed     | 389      |
# |    total_timesteps  | 18138    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 820      |
# |    fps              | 46       |
# |    time_elapsed     | 390      |
# |    total_timesteps  | 18196    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 824      |
# |    fps              | 46       |
# |    time_elapsed     | 393      |
# |    total_timesteps  | 18304    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 828      |
# |    fps              | 46       |
# |    time_elapsed     | 394      |
# |    total_timesteps  | 18374    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 832      |
# |    fps              | 46       |
# |    time_elapsed     | 397      |
# |    total_timesteps  | 18489    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 836      |
# |    fps              | 46       |
# |    time_elapsed     | 399      |
# |    total_timesteps  | 18595    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 840      |
# |    fps              | 46       |
# |    time_elapsed     | 401      |
# |    total_timesteps  | 18682    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 844      |
# |    fps              | 46       |
# |    time_elapsed     | 403      |
# |    total_timesteps  | 18787    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 848      |
# |    fps              | 46       |
# |    time_elapsed     | 405      |
# |    total_timesteps  | 18883    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 852      |
# |    fps              | 46       |
# |    time_elapsed     | 407      |
# |    total_timesteps  | 18961    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 856      |
# |    fps              | 46       |
# |    time_elapsed     | 409      |
# |    total_timesteps  | 19048    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 860      |
# |    fps              | 46       |
# |    time_elapsed     | 410      |
# |    total_timesteps  | 19124    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 864      |
# |    fps              | 46       |
# |    time_elapsed     | 412      |
# |    total_timesteps  | 19212    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 868      |
# |    fps              | 46       |
# |    time_elapsed     | 414      |
# |    total_timesteps  | 19321    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 872      |
# |    fps              | 46       |
# |    time_elapsed     | 416      |
# |    total_timesteps  | 19395    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 876      |
# |    fps              | 46       |
# |    time_elapsed     | 418      |
# |    total_timesteps  | 19503    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 880      |
# |    fps              | 46       |
# |    time_elapsed     | 420      |
# |    total_timesteps  | 19582    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 884      |
# |    fps              | 46       |
# |    time_elapsed     | 422      |
# |    total_timesteps  | 19694    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 888      |
# |    fps              | 46       |
# |    time_elapsed     | 425      |
# |    total_timesteps  | 19825    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 892      |
# |    fps              | 46       |
# |    time_elapsed     | 427      |
# |    total_timesteps  | 19918    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 896      |
# |    fps              | 46       |
# |    time_elapsed     | 429      |
# |    total_timesteps  | 19988    |
# ----------------------------------
